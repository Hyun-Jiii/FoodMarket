# %% [markdown]
# ## 제공현황데이터

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
# 시각화 한글폰트 설정
plt.rc('font', family='Malgun Gothic')
sns.set(font="Malgun Gothic",#"NanumGothicCoding", 
rc={"axes.unicode_minus":False}, # 마이너스 부호 깨짐 현상 해결
style='darkgrid')

data1 = pd.read_csv('5. 부산제공현황통계데이터(2017~2022년).csv', encoding='cp949')
data1.tail(2)
# Out:
#          기준년월 지역코드  통합시군구코드  지원센터코드 식품여부 기부물품대분류코드 기부물품중분류코드  이용자수  제공건수  \
# 19254  202212   부산  3000012  S64801    Y     스포츠용품      건강식품   243   323
# 19255  202212   부산  3000012  S64801    Y     스포츠용품   즉석/편의식품     1     1
#
#              제공금액
# 19254  2842818.72
# 19255   210000.00

# %%
data1['기부물품대분류코드'].unique()
# Out:
# array(['스포츠용품', '신선식품', '일상용품', '의류/패션잡화', '가정용품', '의약품/의료용품', '문화용품',
#        nan, '내구소비재', '기타상품'], dtype=object)

# %%
data1[data1['기부물품대분류코드']=='의류/패션잡화']
# Out:
#          기준년월 지역코드  통합시군구코드  지원센터코드 식품여부 기부물품대분류코드 기부물품중분류코드  이용자수  제공건수  \
# 84     201701   부산  3000006  S40001    N   의류/패션잡화        신발    38    38
# 85     201701   부산  3000006  S40001    N   의류/패션잡화      패션잡화     7     7
# 117    201701   부산  3000009  S40201    N   의류/패션잡화      패션잡화    21    21
# 123    201701   부산  3000002  S40301    N   의류/패션잡화        의류     1     1
# 128    201701   부산  3000002  S40301    N   의류/패션잡화        신발    92    92
# ...       ...  ...      ...     ...  ...       ...       ...   ...   ...
# 19124  202212   부산  3000010  S50101    N   의류/패션잡화        신발    18    18
# 19154  202212   부산  3000005  S50701    N   의류/패션잡화        신발    10    10
# 19155  202212   부산  3000005  S50701    N   의류/패션잡화        의류     3     3
# 19187  202212   부산  3000015  S51601    N   의류/패션잡화        신발    29    29
# 19205  202212   부산  3000014  S58201    N   의류/패션잡화        신발     9     9
#
#              제공금액
# 84     4692000.00
# 85       81900.00
# 117     144900.00
# 123      15000.00
# 128    7925163.76
# ...           ...
# 19124   392000.00
# 19154   890000.00
# 19155    90000.00
# 19187  1182508.52
# 19205    63000.00
#
# [508 rows x 10 columns]

# %% [markdown]
# ## 기부자정보 데이터

# %%
main_val = {'S02501':'부산광역푸드뱅크',
            'S03701':'강서구기초푸드뱅크',
            'S64801':'강서구기초푸드마켓',
            'S03601':'금정구기초푸드뱅크',
            'S51401':'금정구푸드마켓',
            'S04101':'기장군기초푸드뱅크',
            'S63901':'기장군기초푸드마켓',
            'S03201':'남구기초푸드뱅크',
            'S48201':'남구기초푸드마켓',
            'S02801':'동구기초푸드뱅크',
            'S64001':'동구기초푸드마켓',
            'S03101':'동래구기초푸드뱅크',
            'S40001':'동래구기초푸드마켓',
            'S03001':'부산진구기초푸드뱅크',
            'S50701':'부산진구기초푸드마켓',
            'S03301':'북구기초푸드뱅크',
            'S40101':'북구기초푸드마켓',
            'S63301':'사상구기초푸드뱅크',
            'S51601':'사상구기초푸드마켓',
            'S03501':'부산사하기초푸드뱅크',
            'S50101':'사하구기초푸드마켓',
            'S02701':'서구기초푸드뱅크',
            'S40301':'서구기초푸드마켓',
            'S03901':'수영구기초푸드뱅크',
            'S58201':'수영구기초푸드마켓',
            'S03801':'연제구기초푸드뱅크',
            'S64701':'연제구기초푸드마켓',
            'S02901':'영도구기초푸드뱅크',
            'S51501':'영도구기초푸드마켓',
            'S02601':'중구기초푸드뱅크',
            'S49001':'중구기초푸드마켓',
            'S03401':'해운대기초푸드뱅크',    
            'S40201':'해운대기초푸드마켓',    
}

# %%
data2 = pd.read_csv('3.부산기부자정보조회(2016~2021년).csv', encoding='cp949')
data2.tail()
# Out:
#          기준년월 지역코드 통합시군구코드  지원센터코드    기부자구분코드 기부사업장종류코드         기부자명  \
# 19594  202112   부산     연제구  S64701         개인      일반가정        개인기부자
# 19595  202112   부산     연제구  S64701  기업(개인사업자)  식품 도,소매업         하나유통
# 19596  202112   부산     연제구  S64701  기업(개인사업자)        기타         중앙철재
# 19597  202112   부산     강서구  S64801         단체  식품제조,가공업  부산광역시농업기술센터
# 19598  202112   부산     강서구  S64801  기업(개인사업자)  식품제조,가공업         코우테이
#
#             기부금액  기부건수  기부자수
# 19594   600000.0     5     5
# 19595  1428330.0     2     1
# 19596   200000.0     1     1
# 19597   500000.0     3     1
# 19598   176000.0     1     1

# %%
data2['지원센터코드'] = data2['지원센터코드'].map(main_val)

# %%
df = data2.groupby('지원센터코드', as_index=False)['기부금액'].sum()

# %%
data2.corr()
# Out:
#           기준년월      기부금액      기부건수      기부자수
# 기준년월  1.000000  0.016959 -0.013438  0.000209
# 기부금액  0.016959  1.000000  0.050731  0.003141
# 기부건수 -0.013438  0.050731  1.000000  0.021082
# 기부자수  0.000209  0.003141  0.021082  1.000000

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19599 entries, 0 to 19598
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   기준년월       19599 non-null  int64
#  1   지역코드       19599 non-null  object
#  2   통합시군구코드    19599 non-null  int64
#  3   지원센터코드     19599 non-null  object
#  4   기부자구분코드    19599 non-null  object
#  5   기부사업장종류코드  19599 non-null  object
#  6   기부자명       19599 non-null  object
#  7   기부금액       19599 non-null  float64
#  8   기부건수       19599 non-null  int64
#  9   기부자수       19599 non-null  int64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 1.5+ MB

# %%
union_gugun = {
3000001:'중구',
3000002:'서구',
3000003:'동구',
3000004:'영도구',
3000005:'부산진구',
3000006:'동래구',
3000007:'남구',
3000008:'북구',
3000009:'해운대구',
3000010:'사하구',
3000011:'금정구',
3000012:'강서구',
3000013:'연제구',
3000014:'수영구',
3000015:'사상구',
3000100:'기장군' 
}

# %%
data2.isna().sum()
# Out:
# 기준년월         0
# 지역코드         0
# 통합시군구코드      0
# 지원센터코드       0
# 기부자구분코드      0
# 기부사업장종류코드    0
# 기부자명         0
# 기부금액         0
# 기부건수         0
# 기부자수         0
# dtype: int64

# %% [markdown]
# ## 분석데이터

# %%
data3 = pd.read_csv('분석전체데이터.csv', encoding='cp949')
data3.tail()
# Out:
#         지원센터코드                  지원센터주소     년         접수금액         제공금액  \
# 120  해운대기초푸드마켓  부산광역시 해운대구 재반로 79(재송동)  2021  423550224.0  413706176.5
# 121  해운대기초푸드뱅크            부산 해운대구 재송1동  2017  251652753.0  299552303.0
# 122  해운대기초푸드뱅크            부산 해운대구 재송1동  2019  369710065.0  407069506.7
# 123  해운대기초푸드뱅크            부산 해운대구 재송1동  2020  542049942.0  667062331.4
# 124  해운대기초푸드뱅크            부산 해운대구 재송1동  2021  639708386.0  784450164.0
#
#           인수금액      이관금액  이용자수         장부금액    장부수량  기부자수  기부건수   제공건수  사업장유형
# 120   86349843  49375954  7875  423550224.0  105002   217   803  30636      1
# 121   47899536         0   985  251652753.0  137557   162  3197  10156      1
# 122   46655561   9296136  1184  369710065.0  174470   224  4793  16249      1
# 123  139893506  10900000   327  542049942.0  175586   278  4876   5969      1
# 124  146049627   3280111   434  639708386.0  273401   359  6049   7414      1

# %%
df1 = data3[data3['년'] == 2021]

# %%
merge_df = pd.merge(df1, df, how='inner', on = '지원센터코드')

# %%
merge_df.drop('년', axis=1, inplace=True)

# %%
merge_df.corr()
# Out:
#            접수금액      제공금액      인수금액      이관금액      이용자수      장부금액      장부수량  \
# 접수금액   1.000000  0.617567  0.062354  0.268466 -0.116051  1.000000 -0.085357
# 제공금액   0.617567  1.000000  0.744624  0.045597  0.196086  0.617567 -0.078407
# 인수금액   0.062354  0.744624  1.000000  0.074393  0.462416  0.062354 -0.029392
# 이관금액   0.268466  0.045597  0.074393  1.000000  0.142020  0.268466 -0.076618
# 이용자수  -0.116051  0.196086  0.462416  0.142020  1.000000 -0.116051 -0.090675
# 장부금액   1.000000  0.617567  0.062354  0.268466 -0.116051  1.000000 -0.085357
# 장부수량  -0.085357 -0.078407 -0.029392 -0.076618 -0.090675 -0.085357  1.000000
# 기부자수   0.794829  0.425775 -0.101100  0.131109 -0.236362  0.794829 -0.178497
# 기부건수   0.736616  0.325329 -0.026148  0.536026 -0.199810  0.736616 -0.108854
# 제공건수   0.176370  0.628175  0.797824  0.251131  0.650030  0.176370 -0.131584
# 사업장유형  0.732651  0.827025  0.406614  0.052362  0.186335  0.732651 -0.093385
# 기부금액   0.897890  0.728545  0.286289  0.284421  0.034356  0.897890 -0.175519
#
#            기부자수      기부건수      제공건수     사업장유형      기부금액
# 접수금액   0.794829  0.736616  0.176370  0.732651  0.897890
# 제공금액   0.425775  0.325329  0.628175  0.827025  0.728545
# 인수금액  -0.101100 -0.026148  0.797824  0.406614  0.286289
# 이관금액   0.131109  0.536026  0.251131  0.052362  0.284421
# 이용자수  -0.236362 -0.199810  0.650030  0.186335  0.034356
# 장부금액   0.794829  0.736616  0.176370  0.732651  0.897890
# 장부수량  -0.178497 -0.108854 -0.131584 -0.093385 -0.175519
# 기부자수   1.000000  0.773985 -0.037576  0.622862  0.694341
# 기부건수   0.773985  1.000000  0.098839  0.385014  0.604587
# 제공건수  -0.037576  0.098839  1.000000  0.411132  0.389403
# 사업장유형  0.622862  0.385014  0.411132  1.000000  0.794305
# 기부금액   0.694341  0.604587  0.389403  0.794305  1.000000

# %% [markdown]
# ### 기부금액을 추가 했을 때 상관관계

# %%
plt.figure(figsize=(10,10))
sns.heatmap(merge_df.corr(), annot=True, cmap='Greens', linewidths=.5, cbar=False)
plt.show()

# %% [markdown]
# ### 분석데이터.csv 전체 상관관계

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data3.corr(), annot=True, cmap='Greens', cbar=False)
plt.show()

# %% [markdown]
# ## 구별로 매핑해서 그래프 그려보기

# %%
data2['통합시군구코드'] = data2['통합시군구코드'].map(union_gugun)

# %%
# data2.to_csv('3.부산기부자정보조회(2016~2021년).csv', index=False, encoding='cp949')

# %%
data2.head()
# Out:
#      기준년월 지역코드 통합시군구코드  지원센터코드    기부자구분코드 기부사업장종류코드            기부자명  \
# 0  201601   부산     연제구  S02501  기업(개인사업자)  식품 도,소매업         신정푸드(주)
# 1  201601   부산     연제구  S02501  기업(개인사업자)  식품제조,가공업            팔구어묵
# 2  201601   부산     연제구  S02501  기업(개인사업자)  식품 도,소매업     코카콜라음료 주식회사
# 3  201601   부산     연제구  S02501  기업(개인사업자)  식품 도,소매업  농업회사법인주식회사 한파밍
# 4  201601   부산     연제구  S02501  기업(개인사업자)  식품제조,가공업            아태물류
#
#          기부금액  기부건수  기부자수
# 0   3360000.0     1     1
# 1     65000.0     6     1
# 2  13533263.0     1     1
# 3    480000.0     1     1
# 4   2500000.0     1     1

# %%
grouping_gugun_money = data2.groupby(['통합시군구코드', '기부자명'], as_index=False)['기부금액'].sum()

# %%
grouping_gugun_money
# Out:
#      통합시군구코드                  기부자명         기부금액
# 0        강서구  (주) 롯데리아-크리스피크림도넛 하단    7815383.0
# 1        강서구             (주)네이처스토어   13777000.0
# 2        강서구               (주)대호식품     642000.0
# 3        강서구                 (주)바로    1145000.0
# 4        강서구              (주)브레드타임     523700.0
# ...      ...                   ...          ...
# 1693    해운대구               해운대제일교회    2400000.0
# 1694    해운대구            해운대종합사회복지관  363534839.0
# 1695    해운대구            홈플러스 센텀시티점     620000.0
# 1696    해운대구            홈플러스 이파란재단    1116000.0
# 1697    해운대구                  홍루이젠    2800300.0
#
# [1698 rows x 3 columns]

# %%
grouping_gugun_money['기부금액'] = grouping_gugun_money['기부금액'].astype(int)

# %%
grouping_gugun_money.to_csv('부산구별기부처(금액).csv', index=False, encoding='cp949')

# %%
def grouping_gugun_money_graph20(gu):
        
        
    top20 = group_gugun_data[group_gugun_data['통합시군구코드'] == gu].sort_values('기부금액', ascending=False).head(20)
    fig = plt.figure()
    fig.set_dpi(300) # DPI 값을 조정하여 레티나 품질로 설정
    sns.barplot(data=top20, x='기부금액', y='기부자명')
    plt.show()

    return st.pyplot(fig)

# %%
grouping_gugun = data2.groupby(['통합시군구코드', '기부자명'], as_index=False)['기부건수'].sum()

# %%
grouping_gugun
# Out:
#      통합시군구코드                  기부자명  기부건수
# 0        강서구  (주) 롯데리아-크리스피크림도넛 하단   277
# 1        강서구             (주)네이처스토어    10
# 2        강서구               (주)대호식품     4
# 3        강서구                 (주)바로     1
# 4        강서구              (주)브레드타임     4
# ...      ...                   ...   ...
# 1693    해운대구               해운대제일교회     1
# 1694    해운대구            해운대종합사회복지관   340
# 1695    해운대구            홈플러스 센텀시티점     1
# 1696    해운대구            홈플러스 이파란재단     1
# 1697    해운대구                  홍루이젠    14
#
# [1698 rows x 3 columns]

# %%
grouping_gugun.to_csv('부산구별기부처.csv', index=False, encoding='cp949')

# %%
def grouping_gugun_graph(gu):
    
    group_gugun_data = pd.read_csv('부산구별기부처.csv', encoding='cp949')
    top20 = group_gugun_data[group_gugun_data['통합시군구코드'] == gu].sort_values('기부건수', ascending=False).head(20)
    fig = plt.figure()
    sns.barplot(data=top20, x='기부건수', y='기부자명')
    plt.show()
    
    return st.pyplot(fig)

# %%
grouping_gugun[grouping_gugun['통합시군구코드'] == '해운대구'].sort_values('기부건수', ascending=False).head(20)
# Out:
#      통합시군구코드               기부자명  기부건수
# 1560    해운대구             (주)오뚜기  2161
# 1599    해운대구          뚜레쥬르 장산역점  2157
# 1680    해운대구       파리바게트 해운대장산점  1970
# 1649    해운대구           자연드림 좌동점  1832
# 1669    해운대구           파리바게뜨 좌동  1794
# 1688    해운대구              플라잉스콘  1322
# 1673    해운대구          파리바게트 반여점  1316
# 1653    해운대구  주식회사 쿱스토어부산(마린시티)  1310
# 1683    해운대구             파티세리 곽  1288
# 1675    해운대구          파리바게트 재송점  1174
# 1598    해운대구           뚜레쥬르 센텀점  1150
# 1679    해운대구       파리바게트 해운대수비점  1139
# 1672    해운대구          파리바게트 마린점  1051
# 1664    해운대구           쿱스토어 장산점   972
# 1585    해운대구               더데이지   910
# 1605    해운대구            롤링핀 장산점   793
# 1573    해운대구               고메빵집   732
# 1682    해운대구        파리바게트해운대센텀점   641
# 1677    해운대구       파리바게트 팔레드시즈점   563
# 1674    해운대구        파리바게트 장산현대점   524

# %%
grouping_data = data2.groupby('기부자명', as_index=False)['기부건수'].sum()

# %%
sort_data = grouping_data.sort_values(by='기부건수',ascending=False)
sort_data
# Out:
#         기부자명   기부건수
# 110   (주)오뚜기  90180
# 522  롯데제과(주)   7618
# 670    북부산상사   6227
# 226    개인기부자   4430
# 917      오뚜기   3371
# ..       ...    ...
# 159   (주)푸드킹      1
# 968     유진유통      1
# 969      유진홍      1
# 973      윤재식      1
# 922     오일나라      1
#
# [1542 rows x 2 columns]

# %%
top21 = sort_data.head(21)

# %%
top21.to_csv('기부건수 top21.csv', encoding='cp949')

# %%
top5 = sort_data.head()

# %%
top10 = sort_data.head(10)

# %%
top20 = top21.iloc[1:]

# %%
def top_donate_grahp():
    top21 = pd.read_csv('기부건수 top21.csv', encoding='cp949')
    top5 = top21.head()
    top20 = top21.iloc[1:]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 시각화 한글폰트 설정
plt.rc('font', family='Malgun Gothic')
sns.set(font="Malgun Gothic",#"NanumGothicCoding", 
rc={"axes.unicode_minus":False}, # 마이너스 부호 깨짐 현상 해결
style='darkgrid')

sns.barplot(y = top20['기부자명'], x = top20['기부건수'])
plt.show()

# %%
sns.barplot(y = top5['기부자명'], x = top5['기부건수'])
plt.show()

# %%
data2['기부자명'].nunique()
# Out:
# 1542

# %%
unique_donors = data2.drop_duplicates(subset='기부자명')
unique_donors.reset_index(drop=True, inplace=True)

# %%
unique_donors = unique_donors[['기부자구분코드', '기부사업장종류코드', '기부자명', '기부금액']]
unique_donors
# Out:
#         기부자구분코드 기부사업장종류코드            기부자명        기부금액
# 0     기업(개인사업자)  식품 도,소매업         신정푸드(주)   3360000.0
# 1     기업(개인사업자)  식품제조,가공업            팔구어묵     65000.0
# 2     기업(개인사업자)  식품 도,소매업     코카콜라음료 주식회사  13533263.0
# 3     기업(개인사업자)  식품 도,소매업  농업회사법인주식회사 한파밍    480000.0
# 4     기업(개인사업자)  식품제조,가공업            아태물류   2500000.0
# ...         ...       ...             ...         ...
# 1537  기업(개인사업자)  식품 도,소매업            서울우유   1405000.0
# 1538  기업(개인사업자)  식품 도,소매업       쿱스토어부산대연점    404530.0
# 1539         단체        기타          금정초등학교   1988400.0
# 1540  기업(개인사업자)  식품제조,가공업     파리바게뜨 민락동방점   1255700.0
# 1541  기업(개인사업자)  식품제조,가공업            코우테이    176000.0
#
# [1542 rows x 4 columns]

# %%
busan_donors = unique_donors.copy()

# %%
busan_donors
# Out:
#         기부자구분코드 기부사업장종류코드            기부자명        기부금액
# 0     기업(개인사업자)  식품 도,소매업         신정푸드(주)   3360000.0
# 1     기업(개인사업자)  식품제조,가공업            팔구어묵     65000.0
# 2     기업(개인사업자)  식품 도,소매업     코카콜라음료 주식회사  13533263.0
# 3     기업(개인사업자)  식품 도,소매업  농업회사법인주식회사 한파밍    480000.0
# 4     기업(개인사업자)  식품제조,가공업            아태물류   2500000.0
# ...         ...       ...             ...         ...
# 1537  기업(개인사업자)  식품 도,소매업            서울우유   1405000.0
# 1538  기업(개인사업자)  식품 도,소매업       쿱스토어부산대연점    404530.0
# 1539         단체        기타          금정초등학교   1988400.0
# 1540  기업(개인사업자)  식품제조,가공업     파리바게뜨 민락동방점   1255700.0
# 1541  기업(개인사업자)  식품제조,가공업            코우테이    176000.0
#
# [1542 rows x 4 columns]

# %%
def find_busan_donors(search):
    busan_donors = pd.read_csv('부산기부처목록.csv', encoding='cp949')
    return busan_donors[busan_donors['기부자명'].str.contains(search)]

# %%
find_busan_donors('어묵')
# Out:
#         기부자구분코드 기부사업장종류코드     기부자명    기부금액
# 1     기업(개인사업자)  식품제조,가공업     팔구어묵   65000
# 202   기업(개인사업자)  식품제조,가공업     선우어묵  356000
# 741   기업(개인사업자)  식품제조,가공업     대원어묵  510000
# 1145  기업(개인사업자)  식품제조,가공업  (주)효성어묵  595810

# %%
unique_donors['기부금액'] = unique_donors['기부금액'].astype(int)

# %%
unique_donors
# Out:
#         기부자구분코드 기부사업장종류코드            기부자명      기부금액
# 0     기업(개인사업자)  식품 도,소매업         신정푸드(주)   3360000
# 1     기업(개인사업자)  식품제조,가공업            팔구어묵     65000
# 2     기업(개인사업자)  식품 도,소매업     코카콜라음료 주식회사  13533263
# 3     기업(개인사업자)  식품 도,소매업  농업회사법인주식회사 한파밍    480000
# 4     기업(개인사업자)  식품제조,가공업            아태물류   2500000
# ...         ...       ...             ...       ...
# 1537  기업(개인사업자)  식품 도,소매업            서울우유   1405000
# 1538  기업(개인사업자)  식품 도,소매업       쿱스토어부산대연점    404530
# 1539         단체        기타          금정초등학교   1988400
# 1540  기업(개인사업자)  식품제조,가공업     파리바게뜨 민락동방점   1255700
# 1541  기업(개인사업자)  식품제조,가공업            코우테이    176000
#
# [1542 rows x 4 columns]

# %% [markdown]
# ### 부산 기부처 중복 제거 후 저장

# %%
unique_donors.to_csv('부산기부처목록.csv', encoding='cp949', index=False)

# %%
data2['기부사업장종류코드'].unique()
# Out:
# array(['식품 도,소매업', '식품제조,가공업', '즉석판매,제조가공업', '식품 접객업', '집단 급식소', '기타',
#        '일반가정'], dtype=object)

# %%
def donate(needs):
    donate_info = pd.read_csv('3.부산기부자정보조회(2016~2021년).csv', encoding='cp949')
    if needs == '신선식품':
        matching = '식품 도,소매업'
    elif needs == '일상용품' or needs == '의류/패션잡화':
        matching = '즉선판매,제조가공업'
    else:
        matching = '기타'
    donater = donate_info[donate_info['기부사업장종류코드'] == matching]
    donater_list = list(donater['기부자명'].unique())
    return donater_list

# %%
donate('스포츠')

# %%
doso = data2[data2['기부사업장종류코드'] =='식품 도,소매업']
doso['기부자명'].unique()

# %%
doso = data2[(data2['기부사업장종류코드'] =='식품제조,가공업') | (data2['기부사업장종류코드'] =='식품 도,소매업')]
len(doso['기부자명'].unique())
# Out:
# 1153

# %%
group_store = data2[data2['기부사업장종류코드'] == '집단 급식소']

# %%
group_store['기부자명'].unique()

# %%
etc = data2[data2['기부사업장종류코드'] == '기타']
etc['기부자명'].unique()
# etc[etc['기부자명'].str.contains('쌀')]

# %%
# 함수 생성
def inventory(code_name):
    test = pd.read_csv('기부물품대분류(가짜데이터).csv', encoding='cp949')
    test.set_index(test.columns[0], inplace=True)
    return test.loc[code_name, '재고수량']

# %%
inventory('일상용품')

# %%
test = pd.read_csv('기부물품대분류(가짜데이터).csv', encoding='cp949')
test

# %% [markdown]
# ## 새로운 기부처 발굴

# %%
new = pd.read_csv('부산도소매업(전처리).csv', encoding='cp949')
pd.set_option('display.max_columns', None)

# %%
new.tail()
# Out:
#       Unnamed: 0      상호명 상권업종대분류명             표준산업분류명  시군구명  \
# 8145        8145    기린아식품       소매   채소, 과실 및 뿌리작물 소매업  해운대구
# 8146        8146     장가상회       소매       건어물 및 젓갈류 소매업  부산진구
# 8147        8147     떡봄시루       음식              떡류 제조업   연제구
# 8148        8148  호주면세점부산       소매         건강 보조식품 소매업  부산진구
# 8149        8149  해피노이스토어       소매  기타 음ㆍ식료품 위주 종합 소매업   사상구
#
#                        도로명주소          경도         위도
# 8145   부산광역시 해운대구 좌동로14번길 32  129.171069  35.167681
# 8146  부산광역시 부산진구 범일로142번길 39  129.061568  35.142820
# 8147       부산광역시 연제구 과정로 207  129.104707  35.187531
# 8148       부산광역시 부산진구 성지로 79  129.053699  35.177602
# 8149       부산광역시 사상구 사상로 482  128.987760  35.187478

# %%
new['표준산업분류명'].unique()
# Out:
# array(['떡류 제조업', '기타 음ㆍ식료품 위주 종합 소매업', '육류 소매업', '신선, 냉동 및 기타 수산물 소매업',
#        '빵류, 과자류 및 당류 소매업', '건강 보조식품 소매업', '채소, 과실 및 뿌리작물 소매업', '슈퍼마켓',
#        '기타 식료품 소매업', '조리 반찬류 소매업', '음료 소매업', '건어물 및 젓갈류 소매업', '곡물 제분업',
#        '기타 식사용 가공처리 조리식품 제조업', '기타 곡물 가공품 제조업', '비알코올 음료 도매업', '도시락류 제조업',
#        '기타 과실ㆍ채소 가공 및 저장 처리업', '인삼식품 제조업', '기타 비알코올 음료 제조업'], dtype=object)

# %%
new = pd.read_csv('부산도소매업(전처리).csv', encoding='cp949')
new_comp_name = list(new['표준산업분류명'].unique())
new_comp_gugun = list(new['시군구명'].unique())

# %%
new['표준산업분류명'].nunique()
# Out:
# 20

# %%
new[new['시군구명'] == '동구']
# Out:
#       Unnamed: 0           상호명 상권업종대분류명              표준산업분류명 시군구명  \
# 0              0          봄동떡방       음식               떡류 제조업   동구
# 1              1         새마을상회       소매   기타 음ㆍ식료품 위주 종합 소매업   동구
# 43            43  세븐일레븐부산동구동양점       소매   기타 음ㆍ식료품 위주 종합 소매업   동구
# 74            74          한국마트       소매                 슈퍼마켓   동구
# 84            84          브로코스       소매          건강 보조식품 소매업   동구
# ...          ...           ...      ...                  ...  ...
# 7999        7999           럭키7       소매   기타 음ㆍ식료품 위주 종합 소매업   동구
# 8006        8006            싱싱       소매    채소, 과실 및 뿌리작물 소매업   동구
# 8090        8090         크랍스시웍       소매   기타 음ㆍ식료품 위주 종합 소매업   동구
# 8091        8091          부산수산       소매  신선, 냉동 및 기타 수산물 소매업   동구
# 8129        8129          수정유통       소매    채소, 과실 및 뿌리작물 소매업   동구
#
#                         도로명주소          경도         위도
# 0       부산광역시 동구 중앙대로361번길 40  129.046162  35.129181
# 1          부산광역시 동구 영초길 179-1  129.035602  35.116688
# 43           부산광역시 동구 증산로 150  129.053258  35.139179
# 74           부산광역시 동구 망양로 897  129.049507  35.140176
# 84          부산광역시 동구 중앙대로 319  129.044817  35.125263
# ...                       ...         ...        ...
# 7999     부산광역시 동구 대영로243번길 55  129.038384  35.114609
# 8006      부산광역시 동구 초량중로 115-1  129.040781  35.121908
# 8090     부산광역시 동구 대영로243번길 69  129.038743  35.115183
# 8091  부산광역시 동구 망양로476번길 16-10  129.034300  35.116086
# 8129    부산광역시 동구 중앙대로371번길 39  129.046673  35.129699
#
# [299 rows x 8 columns]

# %%
# selected_gugun = '동구'
# selected_comp_name = '떡류 제조업'

# %%
def find_new_donors(selected_gugun, selected_comp_name):
    find_new = new[(new['표준산업분류명'] == selected_comp_name) & (new['시군구명'] == selected_gugun)][['상호명', '표준산업분류명', '시군구명', '도로명주소','위도', '경도']]
    return find_new

# %%
find_new_donors('동구', '떡류 제조업')
# Out:
#          상호명 표준산업분류명 시군구명                   도로명주소         위도          경도
# 0       봄동떡방  떡류 제조업   동구   부산광역시 동구 중앙대로361번길 40  35.129181  129.046162
# 540   연동떡방앗간  떡류 제조업   동구     부산광역시 동구 성남이로46번길 5  35.133423  129.057002
# 2341    부부떡집  떡류 제조업   동구     부산광역시 동구 망양로689번길 3  35.127317  129.040707
# 2479  고향떡방앗간  떡류 제조업   동구     부산광역시 동구 초량로13번길 27  35.117797  129.039851
# 2513  범일떡방앗간  떡류 제조업   동구         부산광역시 동구 범상로 38  35.143609  129.048695
# 2514  일월떡방앗간  떡류 제조업   동구        부산광역시 동구 고관로 113  35.128935  129.046510
# 2729    희망떡집  떡류 제조업   동구      부산광역시 동구 망양로 869-1  35.138343  129.047772
# 2794     떡사랑  떡류 제조업   동구         부산광역시 동구 범일로 91  35.138245  129.059117
# 2825    평양떡집  떡류 제조업   동구   부산광역시 동구 고관로13번길 74-7  35.122216  129.038536
# 2853    한닢꿀떡  떡류 제조업   동구      부산광역시 동구 홍곡남로 53-1  35.125662  129.035058
# 2858       떡  떡류 제조업   동구     부산광역시 동구 중앙대로 529-1  35.140550  129.056260
# 3343    양동떡집  떡류 제조업   동구    부산광역시 동구 망양로870번길 16  35.137599  129.048366
# 4379  풍년떡방앗간  떡류 제조업   동구  부산광역시 동구 중앙대로195번가길 50  35.117362  129.038035
# 4783     우리떡  떡류 제조업   동구      부산광역시 동구 홍곡로58번길 5  35.124506  129.041593
# 5215  성동떡방앗간  떡류 제조업   동구      부산광역시 동구 증산로 181-1  35.139728  129.051312
# 6437  맛고을떡전문  떡류 제조업   동구       부산광역시 동구 수정로 22-1  35.128255  129.044801

# %%
find_new_donors('동구', '떡류 제조업')[['위도', '경도']]
# Out:
#              위도          경도
# 0     35.129181  129.046162
# 540   35.133423  129.057002
# 2341  35.127317  129.040707
# 2479  35.117797  129.039851
# 2513  35.143609  129.048695
# 2514  35.128935  129.046510
# 2729  35.138343  129.047772
# 2794  35.138245  129.059117
# 2825  35.122216  129.038536
# 2853  35.125662  129.035058
# 2858  35.140550  129.056260
# 3343  35.137599  129.048366
# 4379  35.117362  129.038035
# 4783  35.124506  129.041593
# 5215  35.139728  129.051312
# 6437  35.128255  129.044801

# %%
def find_new_donors_location(df):
    # 지도 찍기
    # 라이브러리
    import folium
    import webbrowser
    from folium import IFrame
    import urllib.parse

    # 맵 생성
    map = folium.Map(location=[df['위도'].mean(), df['경도'].mean()], zoom_start=11)

   
    
    # 데이터프레임의 각 위치에 마커 추가
    for i in df.index:
        name = df.loc[i, '상호명']
        gugun = df.loc[i, '시군구명']
        location = df.loc[i, '도로명주소']
        cls1 = df.loc[i, '표준산업분류명']
        
        # 네이버 검색 결과 링크 생성
        encoded_name = urllib.parse.quote(name)
        naver_search_link = f'https://search.naver.com/search.naver?query={encoded_name}&sm=top_hty&fbm=1&ie=utf8'

        # 팝업 내용 생성
        popup_content = f'<div style="font-family: Arial, sans-serif; font-size: 14px;">\
        <a href="{naver_search_link}" target="_blank">{name}</a><br>{location}</div>'
        popup = folium.Popup(popup_content, max_width=250)

        # IFrame을 사용하여 수평으로 표시되도록 팝업 설정
        popup = folium.Popup(IFrame(html=popup_content, width=200, height=80))

        # 마커 생성 및 팝업 추가
        marker = folium.Marker(
                location=[df.loc[i, '위도'], df.loc[i, '경도']],
                icon=folium.Icon(icon='cloud'),
                popup=popup
        )
        marker.add_to(map)


    # 출력 화면에 맵 열기
    return map

# %%
find_new_donors_location(df)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4a7d4f0f783d1bed00e90a206c7d5e21 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4a7d4f0f783d1bed00e90a206c7d5e21&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4a7d4f0f783d1bed00e90a206c7d5e21 = L.map(
#                 &quot;map_4a7d4f0f783d1bed00e90a206c7d5e21&quot;,
#                 {
#                     center: [35.13079544053002, 129.04623605913693],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3eebdfcc921430de7a4a136633df89e5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4a7d4f0f783d1bed00e90a206c7d5e21);
#
#
#             var marker_73776108fc76364539d771b2b4618deb = L.marker(
#                 [35.1291810952931, 129.046162070694],
#                 {}
#             ).addTo(map_4a7d4f0f783d1bed00e90a206c7d5e21);
#
#
#             var icon_5500a1063504da244e1a8a43948fb812 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_73776108fc76364539d771b2b4618deb.setIcon(icon_5500a1063504da244e1a8a43948fb812);
#
#
#         var popup_b73610ac2637c095716909f3b115a35d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var i_frame_7355600641f025a3a764b72c6a86b5fa = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,&quot; width=&quot;200&quot; style=&quot;border:none !important;&quot; height=&quot;80&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_b73610ac2637c095716909f3b115a35d.setContent(i_frame_7355600641f025a3a764b72c6a86b5fa);
#
#
#
#         marker_73776108fc76364539d771b2b4618deb.bindPopup(popup_b73610ac2637c095716909f3b115a35d)
#         ;
#
#
#
#
#             var marker_1f9d0dfd6688e79c2d3fe83a9af42281 = L.marker(
#                 [35.1334227539189, 129.057002353553],
#                 {}
#             ).addTo(map_4a7d4f0f783d1bed00e90a206c7d5e21);
#
#
#             var icon_8b59ebc0f782c2dae4cd124f868e7154 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1f9d0dfd6688e79c2d3fe83a9af42281.setIcon(icon_8b59ebc0f782c2dae4cd124f868e7154);
#
#
#         var popup_200a30523709919cdcd15c64b23f73f1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var i_frame_e5243758bb66c482f93ba601a8525977 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,&quot; width=&quot;200&quot; style=&quot;border:none !important;&quot; height=&quot;80&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_200a30523709919cdcd15c64b23f73f1.setContent(i_frame_e5243758bb66c482f93ba601a8525977);
#
#
#
#         marker_1f9d0dfd6688e79c2d3fe83a9af42281.bindPopup(popup_200a30523709919cdcd15c64b23f73f1)
#         ;
#
#
#
#
#             var marker_743d0111bb883d386defc63ecd552be8 = L.marker(
#                 [35.1273170940771, 129.040707214606],
#                 {}
#             ).addTo(map_4a7d4f0f783d1bed00e90a206c7d5e21);
#
#
#             var icon_698632d452ce3706f5b10d959e43c1c8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_743d0111bb883d386defc63ecd552be8.setIcon(icon_698632d452ce3706f5b10d959e43c1c8);
#
#
#         var popup_178c09e560c3a1da07f0183cdf241617 = L.popup({&quot;maxWidth&quot;: &q

# %%
df = find_new_donors('동구', '떡류 제조업')

# %%
selected_gugun = '동구'
selected_comp_name = '떡류 제조업'

# %%
# 지도 찍기
# 라이브러리
import folium
import webbrowser
from folium import IFrame

# 맵 생성
map = folium.Map(location=[df['위도'].mean(), df['경도'].mean()], zoom_start=11)

    # # 데이터프레임의 각 위치에 마커 추가
for i in df.index:
    name = df.loc[i, '상호명']
    gugun = df.loc[i, '시군구명']
    location = df.loc[i, '도로명주소']
    cls1 = df.loc[i, '표준산업분류명']

    # 팝업 내용 지정(폰트 설정 등..)
    popup_content = f'<div style="font-family: Arial, sans-serif; font-size: 14px;"> [{i}]<br>{location}'

    # IFrame을 사용하여 수평으로 표시되도록 팝업 설정
    popup = folium.Popup(IFrame(html=popup_content, width=200, height=80))

    # 마커 생성 및 팝업 추가
    marker = folium.Marker(
            location=[df.loc[i, '위도'], df.loc[i, '경도']],
            icon=folium.Icon(icon='cloud'),
            popup=popup
    )
    marker.add_to(map)


# 출력 화면에 맵 열기
map

# %% [markdown]
# ## 물품 연산해보기

# %%
test = pd.read_csv('기부물품대분류(가짜데이터).csv', encoding='cp949')
test
# Out:
#   기부물품대분류코드  재고수량     장부금액
# 0     스포츠용품   251  1757000
# 1      신선식품   521   195000
# 2      일상용품   325  1625000
# 3   의류/패션잡화    11  1216000
# 4      가정용품    10   500000
# 5  의약품/의료용품     5   198000
# 6      문화용품   121   363000
# 7     내구소비재    15        0
# 8      기타상품  1895  5685000

# %%
user_data = pd.read_excel('output3.xlsx')
user_data.tail()
# Out:
#      이름          날짜 기부물품대분류코드  내용  수량
# 34  오태수  2023.06.19      신선식품   빵   2
# 35  오태식  2023.06.19      신선식품   빵   5
# 36  박태정  2023.06.19      신선식품  우유   2
# 37  전태현  2023.06.19      신선식품  우유   1
# 38  김태영  2023.06.19      신선식품  우유   2

# %%
previous = len(user_data)
# Out:
# 39

# %%
user_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   이름         39 non-null     object
#  1   날짜         39 non-null     object
#  2   기부물품대분류코드  39 non-null     object
#  3   내용         39 non-null     object
#  4   수량         39 non-null     int64
# dtypes: int64(1), object(4)
# memory usage: 1.6+ KB

# %%
user_data_group = user_data.groupby('기부물품대분류코드', as_index=False)['수량'].sum()
user_data_group
# Out:
#   기부물품대분류코드  수량
# 0      가정용품   6
# 1      기타상품   1
# 2      문화용품   8
# 3     스포츠용품   7
# 4      신선식품  50
# 5   의류/패션잡화   1
# 6  의약품/의료용품   1
# 7      일상용품   1

# %%
test
# Out:
#   기부물품대분류코드  재고수량     장부금액
# 0     스포츠용품   251  1757000
# 1      신선식품   521   195000
# 2      일상용품   325  1625000
# 3   의류/패션잡화    11  1216000
# 4      가정용품    10   500000
# 5  의약품/의료용품     5   198000
# 6      문화용품   121   363000
# 7     내구소비재    15        0
# 8      기타상품  1895  5685000

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   기부물품대분류코드  9 non-null      object
#  1   재고수량       9 non-null      int64
#  2   장부금액       9 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 344.0+ bytes

# %%
def inventory_cal(code_name):
    test = pd.read_csv('기부물품대분류(가짜데이터).csv', encoding='cp949')
    user_data = pd.read_excel('output3.xlsx')
    user_data_group = user_data.groupby('기부물품대분류코드', as_index=False)['수량'].sum()
    # 사용자 데이터에서 기부 품목 코드와 수량 추출
    user_data_item_code = user_data_group['기부물품대분류코드']
    user_data_quantity = user_data_group['수량']

    # 테스트 데이터에서 기부 품목 코드와 수량 추출
    test_item_code = test['기부물품대분류코드']
    test_quantity = test['재고수량']

    # 기부 품목 코드가 일치하는 경우에만 수량 뺄셈 연산 수행
    result = test_quantity.copy()
    for i in range(len(user_data_quantity)):
        if user_data_item_code[i] in list(test_item_code):
            idx = test_item_code[test_item_code.str.contains(user_data_item_code[i])].index[0]
            # print(user_data_quantity[idx])
            result[idx] -= user_data_quantity[i]
            
    test['재고수량'] = result
    test.set_index(test.columns[0], inplace=True)
    test_val = test.loc[code_name, '재고수량']
    
    return test_val

# %%
# 사용자 데이터에서 기부 품목 코드와 수량 추출
user_data_item_code = user_data_group['기부물품대분류코드']
user_data_quantity = user_data_group['수량']

# 테스트 데이터에서 기부 품목 코드와 수량 추출
test_item_code = test['기부물품대분류코드']
test_quantity = test['재고수량']

# 기부 품목 코드가 일치하는 경우에만 수량 뺄셈 연산 수행
result = test_quantity.copy()
for i in range(len(user_data_quantity)):
    if user_data_item_code[i] in list(test_item_code):
        idx = test_item_code[test_item_code.str.contains(user_data_item_code[i])].index[0]
        # print(user_data_quantity[idx])
        result[idx] -= user_data_quantity[i]
        
test['재고수량'] = result
test
# Out:
#   기부물품대분류코드  재고수량     장부금액
# 0     스포츠용품   244  1757000
# 1      신선식품   471   195000
# 2      일상용품   324  1625000
# 3   의류/패션잡화    10  1216000
# 4      가정용품     4   500000
# 5  의약품/의료용품     4   198000
# 6      문화용품   113   363000
# 7     내구소비재    15        0
# 8      기타상품  1894  5685000

# %%
test.set_index(test.columns[0], inplace=True)
test
# Out:
#            재고수량     장부금액
# 기부물품대분류코드
# 스포츠용품       244  1757000
# 신선식품        471   195000
# 일상용품        324  1625000
# 의류/패션잡화      10  1216000
# 가정용품          4   500000
# 의약품/의료용품      4   198000
# 문화용품        113   363000
# 내구소비재        15        0
# 기타상품       1894  5685000

# %%
test.loc[code_name, '재고수량']
# Out:
# 244

# %%
list(test_item_code)
# Out:
# ['스포츠용품',
#  '신선식품',
#  '일상용품',
#  '의류/패션잡화',
#  '가정용품',
#  '의약품/의료용품',
#  '문화용품',
#  '내구소비재',
#  '기타상품']

# %%
if user_data_item_code[0] in test_item_code:
    print(-1)
else:
    print(1)
# Out:
# 1

# %%
# 이전에 계산된 결과를 유지하기 위한 변수
previous_calculation = None

def inventory_cal(code_name):
    global previous_calculation

    test = pd.read_csv('기부물품대분류(가짜데이터).csv', encoding='cp949')
    user_data = pd.read_excel('output3.xlsx')

    user_data_group = user_data.groupby('기부물품대분류코드', as_index=False)['수량'].sum()
    
    # 사용자 데이터에서 기부 품목 코드와 수량 추출
    user_data_item_code = user_data_group['기부물품대분류코드']
    user_data_quantity = user_data_group['수량']

    # 이전에 계산된 결과가 없는 경우 전체 데이터셋을 읽어옴
    if previous_calculation is None:
        previous_calculation = test.copy()

    # 새로운 행만 선택하여 다시 계산
    for i in range(len(user_data_quantity)):
        if user_data_item_code[i] in list(previous_calculation['기부물품대분류코드']):
            idx = previous_calculation.index[previous_calculation['기부물품대분류코드'].str.contains(user_data_item_code[i])][0]
            previous_quantity = previous_calculation.loc[idx, '재고수량']
            previous_calculation.loc[idx, '재고수량'] = previous_quantity - user_data_quantity[i]

    # 최종 데이터셋 반환
    final_result = previous_calculation.loc[previous_calculation['기부물품대분류코드'] == code_name, '재고수량']
    return final_result

# %%
inventory_cal('스포츠용품')
# Out:
# 0    237
# Name: 재고수량, dtype: int64

# %% [markdown]
# ## 사용한 모든 함수

# %%
# 라이브러리
import pandas as pd
import streamlit as st
import numpy as np
# import plotly.express as px
import os
from urllib.parse import quote
from streamlit_folium import st_folium
import folium
import seaborn as sns
import folium
import matplotlib.pyplot as plt
from datetime import date
from streamlit_folium import folium_static
import re

# 시각화 한글폰트 설정
plt.rc('font', family='Malgun Gothic')
sns.set(font="Malgun Gothic",#"NanumGothicCoding", 
rc={"axes.unicode_minus":False}, # 마이너스 부호 깨짐 현상 해결
style='darkgrid')

# # 이미지 크기 줄이기
# from PIL import Image

# # 원본 이미지 열기
# image = Image.open('ktlogo.png')

# # 이미지 크기 조정
# resized_image = image.resize((100, 100))

# # 조정된 이미지 저장
# resized_image.save('ktlogo.png')

class MyClass:
    def __init__(self):
        pass
    
    # 재고 수량 함수 1
    def inventory(self, code_name):
        test = pd.read_csv('기부물품대분류(가짜데이터).csv', encoding='cp949')
        test.set_index(test.columns[0], inplace=True)
        return test.loc[code_name, '재고수량']

    # 재고 수량 계산 함수 2
    # 계산은 가능하지만 새로운 데이터가 추가되었을 때는 그 파일을 사용하지 못하고 다른 새로운 파일을 사용해야한다.
    # ---> 어떻게 해결해야하나? 방법을 모르겠네
    def inventory_cal(self, code_name):
        test = pd.read_csv('기부물품대분류(가짜데이터).csv', encoding='cp949')
        user_data = pd.read_excel('output3.xlsx')

        user_data_group = user_data.groupby('기부물품대분류코드', as_index=False)['수량'].sum()
        # 사용자 데이터에서 기부 품목 코드와 수량 추출
        user_data_item_code = user_data_group['기부물품대분류코드']
        user_data_quantity = user_data_group['수량']

        # 테스트 데이터에서 기부 품목 코드와 수량 추출
        test_item_code = test['기부물품대분류코드']
        test_quantity = test['재고수량']

        # 기부 품목 코드가 일치하는 경우에만 수량 뺄셈 연산 수행
        result = test_quantity.copy()
        for i in range(len(user_data_quantity)):
            if user_data_item_code[i] in list(test_item_code):
                idx = test_item_code[test_item_code.str.contains(user_data_item_code[i])].index[0]
                result[idx] -= user_data_quantity[i]

        test['재고수량'] = result
        test.set_index(test.columns[0], inplace=True)
        test_val = test.loc[code_name, '재고수량']

        return test_val

    # 기부처 찾기 3
    def donate(self, needs):
        donate_info = pd.read_csv('3.부산기부자정보조회(2016~2021년).csv', encoding='cp949')
        if needs == '신선식품':
            matching = '식품 도,소매업'
        elif needs == '일상용품':
            matching = '즉선판매,제조가공업'
        else:
            matching = '기타'
        donater = donate_info[donate_info['기부사업장종류코드'] == matching]
        donater_list = list(donater['기부자명'].unique())
        return donater_list

    # 부산 기부처 목록 4
    def find_busan_donors(self, search):
        busan_donors = pd.read_csv('부산기부처목록.csv', encoding='cp949')
        return busan_donors[busan_donors['기부자명'].str.contains(search)]

    # 기부처 발굴 5
    def find_new_donors(self, selected_gugun, selected_comp_name):
        find_new = new[(new['표준산업분류명'] == selected_comp_name) & (new['시군구명'] == selected_gugun)][['상호명', '표준산업분류명', '시군구명', '도로명주소','위도', '경도']]
        find_new = find_new.reset_index(drop=True)
        return find_new

    # 지도 함수 6
    def find_new_donors_location(self, df):
        # 라이브러리
        import folium
        import webbrowser
        from folium import IFrame
        import urllib.parse

        # 맵 생성
        map = folium.Map(location=[df['위도'].mean(), df['경도'].mean()], zoom_start=11)

            # 데이터프레임의 각 위치에 마커 추가
        for i in df.index:
            name = df.loc[i, '상호명']
            gugun = df.loc[i, '시군구명']
            location = df.loc[i, '도로명주소']
            cls1 = df.loc[i, '표준산업분류명']

            # 네이버 검색 결과 링크 생성
            encoded_name = urllib.parse.quote(name)
            naver_search_link = f'https://search.naver.com/search.naver?query={encoded_name}&sm=top_hty&fbm=1&ie=utf8'

            # 팝업 내용 생성
            popup_content = f'<div style="font-family: Arial, sans-serif; font-size: 14px;"> \
            상호명 : <a href="{naver_search_link}" target="_blank"> {name}</a><br>{location}</div>'
            popup = folium.Popup(popup_content, max_width=250)

            # IFrame을 사용하여 수평으로 표시되도록 팝업 설정
            popup = folium.Popup(IFrame(html=popup_content, width=200, height=80))

            # 마커 생성 및 팝업 추가
            marker = folium.Marker(
                    location=[df.loc[i, '위도'], df.loc[i, '경도']],
                    icon=folium.Icon(icon='home', color='red'),
                    popup=popup
            )
            marker.add_to(map)


        # 출력 화면에 맵 열기
        return folium_static(map)

    # 구 별 최다 기부처 그래프 Top20 함수 7
    def grouping_gugun_graph20(self, gu):


        top20 = group_gugun_data1[group_gugun_data1['통합시군구코드'] == gu].sort_values('기부건수', ascending=False).head(20)
        fig = plt.figure()
        fig.set_dpi(300) # DPI 값을 조정하여 레티나 품질로 설정
        sns.barplot(data=top20, x='기부건수', y='기부자명')
        plt.title('기부건수 별')
        plt.show()

        return st.pyplot(fig)


    # 금액 별 그래프 함수 8
    def grouping_gugun_money_graph20(self, gu):

        top20 = group_gugun_data2[group_gugun_data2['통합시군구코드'] == gu].sort_values('기부금액', ascending=False).head(20)
        fig = plt.figure()
        fig.set_dpi(300) # DPI 값을 조정하여 레티나 품질로 설정
        sns.barplot(data=top20, x='기부금액', y='기부자명')
        plt.title('기부금액 별')
        plt.show()

        return st.pyplot(fig)

p = MyClass()

# %%
# 재고 수량 함수 1
def inventory(code_name):
    test = pd.read_csv('기부물품대분류(가짜데이터).csv', encoding='cp949')
    test.set_index(test.columns[0], inplace=True)
    return test.loc[code_name, '재고수량']

# 재고 수량 계산 함수 2
# 계산은 가능하지만 새로운 데이터가 추가되었을 때는 그 파일을 사용하지 못하고 다른 새로운 파일을 사용해야한다.
# ---> 어떻게 해결해야하나? 방법을 모르겠네
def inventory_cal(code_name):
    test = pd.read_csv('기부물품대분류(가짜데이터).csv', encoding='cp949')
    user_data = pd.read_excel('output3.xlsx')
    
    user_data_group = user_data.groupby('기부물품대분류코드', as_index=False)['수량'].sum()
    # 사용자 데이터에서 기부 품목 코드와 수량 추출
    user_data_item_code = user_data_group['기부물품대분류코드']
    user_data_quantity = user_data_group['수량']

    # 테스트 데이터에서 기부 품목 코드와 수량 추출
    test_item_code = test['기부물품대분류코드']
    test_quantity = test['재고수량']

    # 기부 품목 코드가 일치하는 경우에만 수량 뺄셈 연산 수행
    result = test_quantity.copy()
    for i in range(len(user_data_quantity)):
        if user_data_item_code[i] in list(test_item_code):
            idx = test_item_code[test_item_code.str.contains(user_data_item_code[i])].index[0]
            result[idx] -= user_data_quantity[i]
            
    test['재고수량'] = result
    test.set_index(test.columns[0], inplace=True)
    test_val = test.loc[code_name, '재고수량']
    
    return test_val

# 기부처 찾기 3
def donate(needs):
    donate_info = pd.read_csv('3.부산기부자정보조회(2016~2021년).csv', encoding='cp949')
    if needs == '신선식품':
        matching = '식품 도,소매업'
    elif needs == '일상용품':
        matching = '즉선판매,제조가공업'
    else:
        matching = '기타'
    donater = donate_info[donate_info['기부사업장종류코드'] == matching]
    donater_list = list(donater['기부자명'].unique())
    return donater_list

# 부산 기부처 목록 4
def find_busan_donors(search):
    busan_donors = pd.read_csv('부산기부처목록.csv', encoding='cp949')
    return busan_donors[busan_donors['기부자명'].str.contains(search)]

# 기부처 발굴 5
def find_new_donors(selected_gugun, selected_comp_name):
    find_new = new[(new['표준산업분류명'] == selected_comp_name) & (new['시군구명'] == selected_gugun)][['상호명', '표준산업분류명', '시군구명', '도로명주소','위도', '경도']]
    find_new = find_new.reset_index(drop=True)
    return find_new

# 지도 함수 6
def find_new_donors_location(df):
    # 라이브러리
    import folium
    import webbrowser
    from folium import IFrame
    import urllib.parse
    
    # 맵 생성
    map = folium.Map(location=[df['위도'].mean(), df['경도'].mean()], zoom_start=11)

        # 데이터프레임의 각 위치에 마커 추가
    for i in df.index:
        name = df.loc[i, '상호명']
        gugun = df.loc[i, '시군구명']
        location = df.loc[i, '도로명주소']
        cls1 = df.loc[i, '표준산업분류명']

        # 네이버 검색 결과 링크 생성
        encoded_name = urllib.parse.quote(name)
        naver_search_link = f'https://search.naver.com/search.naver?query={encoded_name}&sm=top_hty&fbm=1&ie=utf8'

        # 팝업 내용 생성
        popup_content = f'<div style="font-family: Arial, sans-serif; font-size: 14px;"> \
        상호명 : <a href="{naver_search_link}" target="_blank"> {name}</a><br>{location}</div>'
        popup = folium.Popup(popup_content, max_width=250)

        # IFrame을 사용하여 수평으로 표시되도록 팝업 설정
        popup = folium.Popup(IFrame(html=popup_content, width=200, height=80))

        # 마커 생성 및 팝업 추가
        marker = folium.Marker(
                location=[df.loc[i, '위도'], df.loc[i, '경도']],
                icon=folium.Icon(icon='home', color='red'),
                popup=popup
        )
        marker.add_to(map)


    # 출력 화면에 맵 열기
    return folium_static(map)

# 구 별 최다 기부처 그래프 Top20 함수 7
def grouping_gugun_graph20(gu):
        
        
    top20 = group_gugun_data1[group_gugun_data1['통합시군구코드'] == gu].sort_values('기부건수', ascending=False).head(20)
    fig = plt.figure()
    fig.set_dpi(300) # DPI 값을 조정하여 레티나 품질로 설정
    sns.barplot(data=top20, x='기부건수', y='기부자명')
    plt.title('기부건수 별')
    plt.show()

    return st.pyplot(fig)


# 금액 별 그래프 함수 8
def grouping_gugun_money_graph20(gu):
        
    top20 = group_gugun_data2[group_gugun_data2['통합시군구코드'] == gu].sort_values('기부금액', ascending=False).head(20)
    fig = plt.figure()
    fig.set_dpi(300) # DPI 값을 조정하여 레티나 품질로 설정
    sns.barplot(data=top20, x='기부금액', y='기부자명')
    plt.title('기부금액 별')
    plt.show()

    return st.pyplot(fig)
